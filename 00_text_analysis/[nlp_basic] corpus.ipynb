# %%
import nltk
nltk.download('gutenberg')
from nltk.corpus import gutenberg
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.

# %% [markdown]
# ### load corpus

# %%
files = gutenberg.fileids()
files # access the list of file identifiers
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
data = gutenberg.raw('austen-emma.txt')

# %%
emma_words = gutenberg.words('austen-emma.txt')
emma_words[:10]
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', 'VOLUME', 'I', 'CHAPTER']

# %%
emma_sentences = gutenberg.sents('austen-emma.txt')
emma_sentences[:3]
# Out:
# [['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']'],
#  ['VOLUME', 'I'],
#  ['CHAPTER', 'I']]

# %%
len(emma_sentences)
# Out:
# 7717

# %% [markdown]
# ### Build a FREQUENCY DISTRIBUTION OF TOKENS OF A TEXT FILE

# %%
from nltk.tokenize import word_tokenize

# %%
tokens = word_tokenize(data)

# %%
from nltk.probability import FreqDist
fdist=FreqDist(tokens)
fdist
# Out:
# FreqDist({',': 12016, '.': 6346, 'to': 5125, 'the': 4844, 'and': 4653, 'of': 4272, 'I': 3177, '--': 3100, 'a': 3001, "''": 2454, ...})

# %%
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
